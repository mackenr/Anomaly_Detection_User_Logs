# %%
from wrangle import *

# %%
programs = programs_dict()
# Out:
# dict_keys(['All', 'DS', 'Front_End', 'Full_Stack_PHP'])

# %%
ds = programs["DS"]
full_stack = programs["Full_Stack_PHP"]
front_end = programs["Front_End"]

# %% [markdown]
# # Questions:

# %% [markdown]
# ## 1. Which lesson appears to attract the most traffic consistently across cohorts (per program)?

# %%
# Question 1
# 1. Which lesson appears to attract the most traffic consistently across cohorts (per program)?


ds_q1 = q1(ds)
ds_q1
# Out:
# <style type="text/css">
# </style>
# <table id="T_3173e">
#   <caption>Q1 DS</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3173e_level0_col0" class="col_heading level0 col0" >lesson</th>
#       <th id="T_3173e_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3173e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3173e_row0_col0" class="data row0 col0" >classification/overview</td>
#       <td id="T_3173e_row0_col1" class="data row0 col1" >1785</td>
#     </tr>
#   </tbody>
# </table>

# %%
full_stack_q1 = q1(full_stack)
full_stack_q1
# Out:
# <style type="text/css">
# </style>
# <table id="T_aea23">
#   <caption>Q1 Full_Stack_PHP</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aea23_level0_col0" class="col_heading level0 col0" >lesson</th>
#       <th id="T_aea23_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aea23_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aea23_row0_col0" class="data row0 col0" >javascript-i</td>
#       <td id="T_aea23_row0_col1" class="data row0 col1" >18193</td>
#     </tr>
#   </tbody>
# </table>

# %%
front_end_q1 = q1(front_end)
front_end_q1
# since front end is such a small number I will not use them going forward
# Out:
# <style type="text/css">
# </style>
# <table id="T_0c1eb">
#   <caption>Q1 Front_End</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c1eb_level0_col0" class="col_heading level0 col0" >lesson</th>
#       <th id="T_0c1eb_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c1eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0c1eb_row0_col0" class="data row0 col0" >content/html-css</td>
#       <td id="T_0c1eb_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---
# <br>
#
# ---

# %% [markdown]
# ## 2. Is there a cohort that referred to a lesson significantly more than other cohorts seemed to gloss over?

# %%
# Question 2
# 2. Is there a cohort that referred to a lesson significantly more than other cohorts seemed to gloss over?

ds_q2 = question2(ds)
ds_q2
# Out:
# <style type="text/css">
# </style>
# <table id="T_5785d">
#   <caption>Q2 DS</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5785d_level0_col0" class="col_heading level0 col0" >lesson</th>
#       <th id="T_5785d_level0_col1" class="col_heading level0 col1" >max_z_score</th>
#       <th id="T_5785d_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_5785d_level0_col3" class="col_heading level0 col3" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5785d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5785d_row0_col0" class="data row0 col0" >anomaly-detection/overview</td>
#       <td id="T_5785d_row0_col1" class="data row0 col1" >1.767054</td>
#       <td id="T_5785d_row0_col2" class="data row0 col2" >Darden</td>
#       <td id="T_5785d_row0_col3" class="data row0 col3" >592</td>
#     </tr>
#     <tr>
#       <th id="T_5785d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5785d_row1_col0" class="data row1 col0" >sql/mysql-overview</td>
#       <td id="T_5785d_row1_col1" class="data row1 col1" >1.682628</td>
#       <td id="T_5785d_row1_col2" class="data row1 col2" >Darden</td>
#       <td id="T_5785d_row1_col3" class="data row1 col3" >774</td>
#     </tr>
#     <tr>
#       <th id="T_5785d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5785d_row2_col0" class="data row2 col0" >classification/overview</td>
#       <td id="T_5785d_row2_col1" class="data row2 col1" >1.667019</td>
#       <td id="T_5785d_row2_col2" class="data row2 col2" >Darden</td>
#       <td id="T_5785d_row2_col3" class="data row2 col3" >1109</td>
#     </tr>
#     <tr>
#       <th id="T_5785d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5785d_row3_col0" class="data row3 col0" >fundamentals/intro-to-data-science</td>
#       <td id="T_5785d_row3_col1" class="data row3 col1" >1.416839</td>
#       <td id="T_5785d_row3_col2" class="data row3 col2" >Florence</td>
#       <td id="T_5785d_row3_col3" class="data row3 col3" >615</td>
#     </tr>
#     <tr>
#       <th id="T_5785d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5785d_row4_col0" class="data row4 col0" >3-sql/1-mysql-overview</td>
#       <td id="T_5785d_row4_col1" class="data row4 col1" >1.413467</td>
#       <td id="T_5785d_row4_col2" class="data row4 col2" >Curie</td>
#       <td id="T_5785d_row4_col3" class="data row4 col3" >441</td>
#     </tr>
#     <tr>
#       <th id="T_5785d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5785d_row5_col0" class="data row5 col0" >stats/compare-means</td>
#       <td id="T_5785d_row5_col1" class="data row5 col1" >1.342333</td>
#       <td id="T_5785d_row5_col2" class="data row5 col2" >Darden</td>
#       <td id="T_5785d_row5_col3" class="data row5 col3" >423</td>
#     </tr>
#     <tr>
#       <th id="T_5785d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5785d_row6_col0" class="data row6 col0" >1-fundamentals/1.1-intro-to-data-science</td>
#       <td id="T_5785d_row6_col1" class="data row6 col1" >1.135807</td>
#       <td id="T_5785d_row6_col2" class="data row6 col2" >Bayes</td>
#       <td id="T_5785d_row6_col3" class="data row6 col3" >640</td>
#     </tr>
#     <tr>
#       <th id="T_5785d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5785d_row7_col0" class="data row7 col0" >python/data-types-and-variables</td>
#       <td id="T_5785d_row7_col1" class="data row7 col1" >1.043553</td>
#       <td id="T_5785d_row7_col2" class="data row7 col2" >Florence</td>
#       <td id="T_5785d_row7_col3" class="data row7 col3" >258</td>
#     </tr>
#     <tr>
#       <th id="T_5785d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5785d_row8_col0" class="data row8 col0" >1-fundamentals/1.2-data-science-pipeline</td>
#       <td id="T_5785d_row8_col1" class="data row8 col1" >0.969793</td>
#       <td id="T_5785d_row8_col2" class="data row8 col2" >Darden</td>
#       <td id="T_5785d_row8_col3" class="data row8 col3" >284</td>
#     </tr>
#     <tr>
#       <th id="T_5785d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5785d_row9_col0" class="data row9 col0" >6-regression/1-overview</td>
#       <td id="T_5785d_row9_col1" class="data row9 col1" >0.689207</td>
#       <td id="T_5785d_row9_col2" class="data row9 col2" >Curie</td>
#       <td id="T_5785d_row9_col3" class="data row9 col3" >595</td>
#     </tr>
#     <tr>
#       <th id="T_5785d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5785d_row10_col0" class="data row10 col0" >10-anomaly-detection/1-overview</td>
#       <td id="T_5785d_row10_col1" class="data row10 col1" >0.672700</td>
#       <td id="T_5785d_row10_col2" class="data row10 col2" >Bayes</td>
#       <td id="T_5785d_row10_col3" class="data row10 col3" >384</td>
#     </tr>
#   </tbody>
# </table>

# %%
full_stack_q2 = question2(full_stack[full_stack.name != "Staff"])
full_stack_q2
# Out:
# <style type="text/css">
# </style>
# <table id="T_e66d8">
#   <caption>Q2 Full_Stack_PHP</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e66d8_level0_col0" class="col_heading level0 col0" >lesson</th>
#       <th id="T_e66d8_level0_col1" class="col_heading level0 col1" >max_z_score</th>
#       <th id="T_e66d8_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_e66d8_level0_col3" class="col_heading level0 col3" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e66d8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e66d8_row0_col0" class="data row0 col0" >toc</td>
#       <td id="T_e66d8_row0_col1" class="data row0 col1" >2.893278</td>
#       <td id="T_e66d8_row0_col2" class="data row0 col2" >Jupiter</td>
#       <td id="T_e66d8_row0_col3" class="data row0 col3" >1866</td>
#     </tr>
#     <tr>
#       <th id="T_e66d8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e66d8_row1_col0" class="data row1 col0" >spring</td>
#       <td id="T_e66d8_row1_col1" class="data row1 col1" >1.828492</td>
#       <td id="T_e66d8_row1_col2" class="data row1 col2" >Teddy</td>
#       <td id="T_e66d8_row1_col3" class="data row1 col3" >744</td>
#     </tr>
#     <tr>
#       <th id="T_e66d8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e66d8_row2_col0" class="data row2 col0" >html-css</td>
#       <td id="T_e66d8_row2_col1" class="data row2 col1" >1.797995</td>
#       <td id="T_e66d8_row2_col2" class="data row2 col2" >Jupiter</td>
#       <td id="T_e66d8_row2_col3" class="data row2 col3" >784</td>
#     </tr>
#     <tr>
#       <th id="T_e66d8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e66d8_row3_col0" class="data row3 col0" >java-ii</td>
#       <td id="T_e66d8_row3_col1" class="data row3 col1" >1.669692</td>
#       <td id="T_e66d8_row3_col2" class="data row3 col2" >Voyageurs</td>
#       <td id="T_e66d8_row3_col3" class="data row3 col3" >756</td>
#     </tr>
#     <tr>
#       <th id="T_e66d8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e66d8_row4_col0" class="data row4 col0" >javascript-i</td>
#       <td id="T_e66d8_row4_col1" class="data row4 col1" >1.638452</td>
#       <td id="T_e66d8_row4_col2" class="data row4 col2" >Ceres</td>
#       <td id="T_e66d8_row4_col3" class="data row4 col3" >1003</td>
#     </tr>
#     <tr>
#       <th id="T_e66d8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e66d8_row5_col0" class="data row5 col0" >java-iii</td>
#       <td id="T_e66d8_row5_col1" class="data row5 col1" >1.617244</td>
#       <td id="T_e66d8_row5_col2" class="data row5 col2" >Jupiter</td>
#       <td id="T_e66d8_row5_col3" class="data row5 col3" >795</td>
#     </tr>
#     <tr>
#       <th id="T_e66d8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e66d8_row6_col0" class="data row6 col0" >jquery</td>
#       <td id="T_e66d8_row6_col1" class="data row6 col1" >1.566463</td>
#       <td id="T_e66d8_row6_col2" class="data row6 col2" >Ceres</td>
#       <td id="T_e66d8_row6_col3" class="data row6 col3" >637</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---
# <br>
#
# ---

# %% [markdown]
# ## 3. Are there students who, when active, hardly access the curriculum?
# ## If so, what information do you have about these students?

# %%
# Question 3
# 3. Are there students who, when active, hardly access the curriculum? If so, what information do you have about these students?


question3(ds)
# Out:
#         name   id  count
# 0     Darden  679      4
# 1     Darden  697      7
# 2      Bayes  487     16
# 3     Easley  839     46
# 4   Florence  902    116
# 5   Florence  906    148
# 6     Darden  780    153
# 7   Florence  904    160
# 8   Florence  899    189
# 9   Florence  905    194
# 10  Florence  911    203
# 11  Florence  912    204
# 12  Florence  901    209
# 13     Curie  577    215
# 14    Darden  683    222
# 15  Florence  914    228
# 16  Florence  897    244
# 17    Darden  783    248
# 18  Florence  913    252
# 19  Florence  895    256
# 20  Florence  949    285
# 21    Easley  846    288
# 22  Florence  910    308
# 23  Florence  907    328
# 24     Bayes  477    347
# 25  Florence  896    351
# 26    Darden  693    360

# %%
question3(full_stack[full_stack.name != "Staff"])
# Out:
#           name   id  count
# 0      Jupiter  832      2
# 1         Luna  663      2
# 2    Voyageurs  278      3
# 3       Oberon  956      4
# 4       Europa  539      4
# ..         ...  ...    ...
# 152      Marco  884    306
# 153       Apex  594    310
# 154    Kalypso  797    312
# 155      Marco  871    319
# 156       Luna  830    331
#
# [157 rows x 3 columns]

# %% [markdown]
# ## Yes,we can see the students and respective cohorts they belong to.
# ## They we identified by picking the bottom 25% of access counts with respect to program type.
# ---
# <br>
#
# ---

# %% [markdown]
# ## 4. Is there any suspicious activity, such as users/machines/etc accessing the curriculum who shouldn’t be? Does it appear that any web-scraping is happening? Are there any suspicious IP ##

# %%
# Question 4
# Is there any suspicious activity, such as users/machines/etc accessing the curriculum who shouldn’t be? 
# Does it appear that any web-scraping is happening? Are there any suspicious IP addresses?


q4(ds)

q4(full_stack[full_stack.name != "Staff"])
# Out:
# <style type="text/css">
# </style>
# <table id="T_a8640">
#   <caption>Q4 DS</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8640_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_a8640_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_a8640_level0_col2" class="col_heading level0 col2" >mode</th>
#       <th id="T_a8640_level0_col3" class="col_heading level0 col3" >nunique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8640_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8640_row0_col0" class="data row0 col0" >843</td>
#       <td id="T_a8640_row0_col1" class="data row0 col1" >Easley</td>
#       <td id="T_a8640_row0_col2" class="data row0 col2" >172.58.99.111</td>
#       <td id="T_a8640_row0_col3" class="data row0 col3" >122</td>
#     </tr>
#     <tr>
#       <th id="T_a8640_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a8640_row1_col0" class="data row1 col0" >690</td>
#       <td id="T_a8640_row1_col1" class="data row1 col1" >Darden</td>
#       <td id="T_a8640_row1_col2" class="data row1 col2" >67.11.40.170</td>
#       <td id="T_a8640_row1_col3" class="data row1 col3" >86</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_04b06">
#   <caption>Q4 Full_Stack_PHP</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04b06_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_04b06_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_04b06_level0_col2" class="col_heading level0 col2" >mode</th>
#       <th id="T_04b06_level0_col3" class="col_heading level0 col3" >nunique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04b06_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_04b06_row0_col0" class="data row0 col0" >228</td>
#       <td id="T_04b06_row0_col1" class="data row0 col1" >Wrangell</td>
#       <td id="T_04b06_row0_col2" class="data row0 col2" >97.105.19.58</td>
#       <td id="T_04b06_row0_col3" class="data row0 col3" >148</td>
#     </tr>
#     <tr>
#       <th id="T_04b06_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_04b06_row1_col0" class="data row1 col0" >533</td>
#       <td id="T_04b06_row1_col1" class="data row1 col1" >Europa</td>
#       <td id="T_04b06_row1_col2" class="data row1 col2" >205.251.148.178</td>
#       <td id="T_04b06_row1_col3" class="data row1 col3" >91</td>
#     </tr>
#     <tr>
#       <th id="T_04b06_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_04b06_row2_col0" class="data row2 col0" >530</td>
#       <td id="T_04b06_row2_col1" class="data row2 col1" >Europa</td>
#       <td id="T_04b06_row2_col2" class="data row2 col2" >97.105.19.58</td>
#       <td id="T_04b06_row2_col3" class="data row2 col3" >86</td>
#     </tr>
#     <tr>
#       <th id="T_04b06_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_04b06_row3_col0" class="data row3 col0" >226</td>
#       <td id="T_04b06_row3_col1" class="data row3 col1" >Wrangell</td>
#       <td id="T_04b06_row3_col2" class="data row3 col2" >97.105.19.58</td>
#       <td id="T_04b06_row3_col3" class="data row3 col3" >83</td>
#     </tr>
#     <tr>
#       <th id="T_04b06_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_04b06_row4_col0" class="data row4 col0" >460</td>
#       <td id="T_04b06_row4_col1" class="data row4 col1" >Ceres</td>
#       <td id="T_04b06_row4_col2" class="data row4 col2" >89.187.164.151</td>
#       <td id="T_04b06_row4_col3" class="data row4 col3" >81</td>
#     </tr>
#     <tr>
#       <th id="T_04b06_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_04b06_row5_col0" class="data row5 col0" >127</td>
#       <td id="T_04b06_row5_col1" class="data row5 col1" >Ulysses</td>
#       <td id="T_04b06_row5_col2" class="data row5 col2" >97.105.19.61</td>
#       <td id="T_04b06_row5_col3" class="data row5 col3" >61</td>
#     </tr>
#     <tr>
#       <th id="T_04b06_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_04b06_row6_col0" class="data row6 col0" >337</td>
#       <td id="T_04b06_row6_col1" class="data row6 col1" >Zion</td>
#       <td id="T_04b06_row6_col2" class="data row6 col2" >97.105.19.58</td>
#       <td id="T_04b06_row6_col3" class="data row6 col3" >56</td>
#     </tr>
#     <tr>
#       <th id="T_04b06_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_04b06_row7_col0" class="data row7 col0" >570</td>
#       <td id="T_04b06_row7_col1" class="data row7 col1" >Fortuna</td>
#       <td id="T_04b06_row7_col2" class="data row7 col2" >172.124.67.93</td>
#       <td id="T_04b06_row7_col3" class="data row7 col3" >49</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ###  These ids are suspicious because they have very high number of ips associated with the same id.
# ###  They are above the 95th percentile.
# ###   Due to this high number of IP's it is likely that they are web-scraping
# ### We will explore the question of if they shouldn't be in the next question.
#
# ---
# <br>
#
# ---

# %% [markdown]
# ## 5. At some point in 2019, the ability for students and alumni to access both curriculums (web dev to ds, ds to web dev) should have been shut off.
# ## Do you see any evidence of that happening?
# ## Did it happen before?

# %%
# 5. At some point in 2019, the ability for students and alumni to access both curriculums (web dev to ds, ds to web dev) should have been shut off.
# Do you see any evidence of that happening? Did it happen before?

# %%
q5(ds,full_stack)

# %% [markdown]
# ### I found the common intersection between all DS cohorts.
# ### Using that set I was able to flag all the students in Web dev who were accessing DS materials.
# ### This set was rather conservative so there could in fact be more, nonetheless it clearly shows that access has not been entirely revoked only reduced, and there have been relatively high access past the point in 2019 where access was supposed end.
# ---
# <br>
#
# ---

# %% [markdown]
# ## 6. What topics are grads continuing to reference after graduation and into their jobs (for each program)?

# %%
#6. What topics are grads continuing to reference after graduation and into their jobs (for each program)

q6_ds=q6(ds)
q6_ds
# Out:
# <style type="text/css">
# </style>
# <table id="T_a3425">
#   <caption>Q6 DS</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3425_level0_col0" class="col_heading level0 col0" >lesson</th>
#       <th id="T_a3425_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3425_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a3425_row0_col0" class="data row0 col0" >sql/mysql-overview</td>
#       <td id="T_a3425_row0_col1" class="data row0 col1" >275</td>
#     </tr>
#     <tr>
#       <th id="T_a3425_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a3425_row1_col0" class="data row1 col0" >classification/overview</td>
#       <td id="T_a3425_row1_col1" class="data row1 col1" >267</td>
#     </tr>
#     <tr>
#       <th id="T_a3425_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a3425_row2_col0" class="data row2 col0" >anomaly-detection/overview</td>
#       <td id="T_a3425_row2_col1" class="data row2 col1" >191</td>
#     </tr>
#     <tr>
#       <th id="T_a3425_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a3425_row3_col0" class="data row3 col0" >fundamentals/intro-to-data-science</td>
#       <td id="T_a3425_row3_col1" class="data row3 col1" >184</td>
#     </tr>
#     <tr>
#       <th id="T_a3425_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a3425_row4_col0" class="data row4 col0" >1-fundamentals/1.1-intro-to-data-science</td>
#       <td id="T_a3425_row4_col1" class="data row4 col1" >127</td>
#     </tr>
#     <tr>
#       <th id="T_a3425_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a3425_row5_col0" class="data row5 col0" >sql/database-design</td>
#       <td id="T_a3425_row5_col1" class="data row5 col1" >87</td>
#     </tr>
#     <tr>
#       <th id="T_a3425_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a3425_row6_col0" class="data row6 col0" >6-regression/1-overview</td>
#       <td id="T_a3425_row6_col1" class="data row6 col1" >86</td>
#     </tr>
#     <tr>
#       <th id="T_a3425_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a3425_row7_col0" class="data row7 col0" >classification/prep</td>
#       <td id="T_a3425_row7_col1" class="data row7 col1" >77</td>
#     </tr>
#     <tr>
#       <th id="T_a3425_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a3425_row8_col0" class="data row8 col0" >fundamentals/environment-setup</td>
#       <td id="T_a3425_row8_col1" class="data row8 col1" >76</td>
#     </tr>
#     <tr>
#       <th id="T_a3425_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a3425_row9_col0" class="data row9 col0" >stats/compare-means</td>
#       <td id="T_a3425_row9_col1" class="data row9 col1" >73</td>
#     </tr>
#   </tbody>
# </table>

# %%
q6_full_stack=q6(full_stack[full_stack.name!='Staff'])
q6_full_stack
# Out:
# <style type="text/css">
# </style>
# <table id="T_9221c">
#   <caption>Q6 Full_Stack_PHP</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9221c_level0_col0" class="col_heading level0 col0" >lesson</th>
#       <th id="T_9221c_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9221c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9221c_row0_col0" class="data row0 col0" >javascript-i</td>
#       <td id="T_9221c_row0_col1" class="data row0 col1" >3152</td>
#     </tr>
#     <tr>
#       <th id="T_9221c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9221c_row1_col0" class="data row1 col0" >spring</td>
#       <td id="T_9221c_row1_col1" class="data row1 col1" >2869</td>
#     </tr>
#     <tr>
#       <th id="T_9221c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9221c_row2_col0" class="data row2 col0" >html-css</td>
#       <td id="T_9221c_row2_col1" class="data row2 col1" >2403</td>
#     </tr>
#     <tr>
#       <th id="T_9221c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9221c_row3_col0" class="data row3 col0" >java-i</td>
#       <td id="T_9221c_row3_col1" class="data row3 col1" >2275</td>
#     </tr>
#     <tr>
#       <th id="T_9221c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9221c_row4_col0" class="data row4 col0" >java-ii</td>
#       <td id="T_9221c_row4_col1" class="data row4 col1" >2184</td>
#     </tr>
#     <tr>
#       <th id="T_9221c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9221c_row5_col0" class="data row5 col0" >java-iii</td>
#       <td id="T_9221c_row5_col1" class="data row5 col1" >2148</td>
#     </tr>
#     <tr>
#       <th id="T_9221c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9221c_row6_col0" class="data row6 col0" >javascript-ii</td>
#       <td id="T_9221c_row6_col1" class="data row6 col1" >1988</td>
#     </tr>
#     <tr>
#       <th id="T_9221c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9221c_row7_col0" class="data row7 col0" >appendix</td>
#       <td id="T_9221c_row7_col1" class="data row7 col1" >1798</td>
#     </tr>
#     <tr>
#       <th id="T_9221c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9221c_row8_col0" class="data row8 col0" >mysql</td>
#       <td id="T_9221c_row8_col1" class="data row8 col1" >1689</td>
#     </tr>
#     <tr>
#       <th id="T_9221c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9221c_row9_col0" class="data row9 col0" >toc</td>
#       <td id="T_9221c_row9_col1" class="data row9 col1" >1663</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### We answer this question by presenting the lists above.
# ---
# <br>
#
# ---

# %% [markdown]
# ## 7. Which lessons are least accessed?

# %% [markdown]
# ### We answer the two questions below by selecting lessons accessed the least in Data science and in Web Dev, however since there are multiple sites only accessed once we have a long list for each program.

# %%
#7 Which lessons are least accessed?

q7_ds=q7(ds)
q7_ds
# Out:
# <style type="text/css">
# </style>
# <table id="T_29896">
#   <caption>q7 DS</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29896_level0_col0" class="col_heading level0 col0" >lesson</th>
#       <th id="T_29896_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29896_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_29896_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_29896_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_29896_row1_col0" class="data row1 col0" >12-distributed-ml/3-getting-started</td>
#       <td id="T_29896_row1_col1" class="data row1 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_29896_row2_col0" class="data row2 col0" >12-distributed-ml/4-acquire</td>
#       <td id="T_29896_row2_col1" class="data row2 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_29896_row3_col0" class="data row3 col0" >12-distributed-ml/5-inspect</td>
#       <td id="T_29896_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_29896_row4_col0" class="data row4 col0" >12-distributed-ml/6.1-prepare-part-1</td>
#       <td id="T_29896_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_29896_row5_col0" class="data row5 col0" >12-distributed-ml/6.2-prepare-part-2</td>
#       <td id="T_29896_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_29896_row6_col0" class="data row6 col0" >12-distributed-ml/6.3-prepare-part-3</td>
#       <td id="T_29896_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_29896_row7_col0" class="data row7 col0" >12-distributed-ml/6.4-prepare-part-4</td>
#       <td id="T_29896_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_29896_row8_col0" class="data row8 col0" >12-distributed-ml/8.1-classification</td>
#       <td id="T_29896_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_29896_row9_col0" class="data row9 col0" >12-distributed-ml/spark-topics</td>
#       <td id="T_29896_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_29896_row10_col0" class="data row10 col0" >2-storytelling/chart-types</td>
#       <td id="T_29896_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_29896_row11_col0" class="data row11 col0" >2.1-spreadsheets-overview</td>
#       <td id="T_29896_row11_col1" class="data row11 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_29896_row12_col0" class="data row12 col0" >3-sql</td>
#       <td id="T_29896_row12_col1" class="data row12 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_29896_row13_col0" class="data row13 col0" >3-vocabulary</td>
#       <td id="T_29896_row13_col1" class="data row13 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_29896_row14_col0" class="data row14 col0" >4-python/pandas-lesson</td>
#       <td id="T_29896_row14_col1" class="data row14 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_29896_row15_col0" class="data row15 col0" >4.2-compare-means</td>
#       <td id="T_29896_row15_col1" class="data row15 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_29896_row16_col0" class="data row16 col0" >5-detecting-with-clustering</td>
#       <td id="T_29896_row16_col1" class="data row16 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_29896_row17_col0" class="data row17 col0" >5-stats/4.2-compare-means/null</td>
#       <td id="T_29896_row17_col1" class="data row17 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_29896_row18_col0" class="data row18 col0" >6-regression/8-Project</td>
#       <td id="T_29896_row18_col1" class="data row18 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_29896_row19_col0" class="data row19 col0" >7-classification/confusion-matrix</td>
#       <td id="T_29896_row19_col1" class="data row19 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_29896_row20_col0" class="data row20 col0" >7-classification/svm</td>
#       <td id="T_29896_row20_col1" class="data row20 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_29896_row21_col0" class="data row21 col0" >7.4.1-pandas-overview</td>
#       <td id="T_29896_row21_col1" class="data row21 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_29896_row22_col0" class="data row22 col0" >7.4.2-series</td>
#       <td id="T_29896_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_29896_row23_col0" class="data row23 col0" >9-timeseries/6.1-parametric-modeling</td>
#       <td id="T_29896_row23_col1" class="data row23 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_29896_row24_col0" class="data row24 col0" >9-timeseries/6.2-prophet</td>
#       <td id="T_29896_row24_col1" class="data row24 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_29896_row25_col0" class="data row25 col0" >A-clustering/project</td>
#       <td id="T_29896_row25_col1" class="data row25 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_29896_row26_col0" class="data row26 col0" >End_to_End_clustering</td>
#       <td id="T_29896_row26_col1" class="data row26 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_29896_row27_col0" class="data row27 col0" >acquire-and-prep</td>
#       <td id="T_29896_row27_col1" class="data row27 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_29896_row28_col0" class="data row28 col0" >appendix/cli/2-Overview</td>
#       <td id="T_29896_row28_col1" class="data row28 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_29896_row29_col0" class="data row29 col0" >appendix/cli/2-overview</td>
#       <td id="T_29896_row29_col1" class="data row29 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_29896_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_29896_row30_col0" class="data row30 col0" >appendix/cls/2-

# %%
q7_full_stack=q7(full_stack[full_stack.name!='Staff'])
q7_full_stack
# Out:
# <style type="text/css">
# </style>
# <table id="T_3358e">
#   <caption>q7 Full_Stack_PHP</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3358e_level0_col0" class="col_heading level0 col0" >lesson</th>
#       <th id="T_3358e_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3358e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3358e_row0_col0" class="data row0 col0" >02_listing_files</td>
#       <td id="T_3358e_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3358e_row1_col0" class="data row1 col0" >03_file_paths</td>
#       <td id="T_3358e_row1_col1" class="data row1 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3358e_row2_col0" class="data row2 col0" >04_navigating_the_filesystem</td>
#       <td id="T_3358e_row2_col1" class="data row2 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3358e_row3_col0" class="data row3 col0" >05_creating_files_and_directories</td>
#       <td id="T_3358e_row3_col1" class="data row3 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3358e_row4_col0" class="data row4 col0" >1-fundamentals/2.1-intro-to-excel</td>
#       <td id="T_3358e_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3358e_row5_col0" class="data row5 col0" >1-fundamentals/2.4-more-excel-features</td>
#       <td id="T_3358e_row5_col1" class="data row5 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3358e_row6_col0" class="data row6 col0" >1-fundamentals/project</td>
#       <td id="T_3358e_row6_col1" class="data row6 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3358e_row7_col0" class="data row7 col0" >10.01_Acquire_WebScraping</td>
#       <td id="T_3358e_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3358e_row8_col0" class="data row8 col0" >10.02.01_ParseText</td>
#       <td id="T_3358e_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3358e_row9_col0" class="data row9 col0" >10.02.02_POSTagging</td>
#       <td id="T_3358e_row9_col1" class="data row9 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3358e_row10_col0" class="data row10 col0" >10.02.03_TFIDF</td>
#       <td id="T_3358e_row10_col1" class="data row10 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_3358e_row11_col0" class="data row11 col0" >10.03_Explore</td>
#       <td id="T_3358e_row11_col1" class="data row11 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_3358e_row12_col0" class="data row12 col0" >10.04.01_FeatureExtraction_FreqBased</td>
#       <td id="T_3358e_row12_col1" class="data row12 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_3358e_row13_col0" class="data row13 col0" >10.04.02_FeatureExtraction_Word2Vec</td>
#       <td id="T_3358e_row13_col1" class="data row13 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_3358e_row14_col0" class="data row14 col0" >10.04.03_SentimentAnalysis</td>
#       <td id="T_3358e_row14_col1" class="data row14 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_3358e_row15_col0" class="data row15 col0" >10.04.04_TextClassification</td>
#       <td id="T_3358e_row15_col1" class="data row15 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_3358e_row16_col0" class="data row16 col0" >10.04.05_TopicModeling</td>
#       <td id="T_3358e_row16_col1" class="data row16 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_3358e_row17_col0" class="data row17 col0" >10.10_Exercises</td>
#       <td id="T_3358e_row17_col1" class="data row17 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_3358e_row18_col0" class="data row18 col0" >10.2_Regex</td>
#       <td id="T_3358e_row18_col1" class="data row18 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_3358e_row19_col0" class="data row19 col0" >10._NLP</td>
#       <td id="T_3358e_row19_col1" class="data row19 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_3358e_row20_col0" class="data row20 col0" >11-nlp/1-overview</td>
#       <td id="T_3358e_row20_col1" class="data row20 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_3358e_row21_col0" class="data row21 col0" >11-nlp/topic-modeling</td>
#       <td id="T_3358e_row21_col1" class="data row21 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_3358e_row22_col0" class="data row22 col0" >11.01.02_DataAcquisition</td>
#       <td id="T_3358e_row22_col1" class="data row22 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_3358e_row23_col0" class="data row23 col0" >115</td>
#       <td id="T_3358e_row23_col1" class="data row23 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_3358e_row24_col0" class="data row24 col0" >12.3.6_Page_Styling</td>
#       <td id="T_3358e_row24_col1" class="data row24 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_3358e_row25_col0" class="data row25 col0" >13.01.01_Understand</td>
#       <td id="T_3358e_row25_col1" class="data row25 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_3358e_row26_col0" class="data row26 col0" >13.01.02.01_Prep</td>
#       <td id="T_3358e_row26_col1" class="data row26 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_3358e_row27_col0" class="data row27 col0" >13.01.02.02_TalkAndListen</td>
#       <td id="T_3358e_row27_col1" class="data row27 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_3358e_row28_col0" class="data row28 col0" >13.01.02.03_Sketch</td>
#       <td id="T_3358e_row28_col1" class="data row28 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_3358e_row29_col0" class="data row29 col0" >13.01.02.04_Prototype</td>
#       <td id="T_3358e_row29_col1" class="data row29 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_3358e_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_3358e_row30_col0" class="data row30 col0" >13.01.02_Create</td>
#       <td id="T_3358e_row30_col1" class="data row30 col1" >1</td>
#     </tr>
#     <tr>
